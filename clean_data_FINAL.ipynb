# %% [markdown]
# <a href="https://colab.research.google.com/github/aubrieconger/digitalmethods1/blob/main/clean_data_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = ('/content/Persons_of_Color_Troop_Enlistments_from_Connecticut_during_the_Civil_War.csv')

df = pd.read_csv(file_path)
df.head(200)
# Out:
#     Last name First name MI/name  Regiment Company            Place of birth  \
# 0       Adams      James     NaN        29      I.                  Maryland
# 1       Adams      Henry      A.        29     NaN                    France
# 2       Adams      Henry      E.        29     NaN  Torringford, Connecticut
# 3      Abbott     Wesley     NaN        29     NaN  Madison County, Virginia
# 4       Adams      James      B.        29      F.  Torringford, Connecticut
# ..        ...        ...     ...       ...     ...                       ...
# 195      Camm     Truman     NaN        29      G.     Woodbury, Connecticut
# 196      Camp     Nathan     NaN        29      C.     Hartford, Connecticut
# 197  Campbell    Richard     NaN        29      B.              Pennsylvania
# 198    Camper      Henry     NaN        29      F.                  Virginia
# 199    Camrel      James     NaN        30      B.      Jamaica, West Indies
#
# ...

# %%
df.info('/content/Persons_of_Color_Troop_Enlistments_from_Connecticut_during_the_Civil_War.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1699 entries, 0 to 1698
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Last name            1698 non-null   object
#  1   First name           1699 non-null   object
#  2   MI/name              491 non-null    object
#  3   Regiment             1699 non-null   int64
#  4   Company              1301 non-null   object
#  5   Place of birth       1696 non-null   object
#  6   Enlistment date      1699 non-null   object
#  7   Enlistment location  1699 non-null   object
#  8   Residence            881 non-null    object
#  9   Age                  1698 non-null   object
#  10  Occupation           1694 non-null   object
#  11  Marital status       774 non-null    object
#  12  Complexion           1696 non-null   object
#  13  Wounded              0 non-null      float64
#  14  Died in service      0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# Last name                 1
# First name                0
# MI/name                1208
# Regiment                  0
# Company                 398
# Place of birth            3
# Enlistment date           0
# Enlistment location       0
# Residence               818
# Age                       1
# Occupation                5
# Marital status          925
# Complexion                3
# Wounded                1699
# Died in service        1699
# Muster out date        1699
# Sign name                 0
# Substitue                 0
# Substitute for         1581
# Box                       0
# Folder                   75
# Notes                  1644
# dtype: int64

# %%
df.drop(columns='Wounded')
# Out:
#       Last name First name MI/name  Regiment Company  \
# 0         Adams      James     NaN        29      I.
# 1         Adams      Henry      A.        29     NaN
# 2         Adams      Henry      E.        29     NaN
# 3        Abbott     Wesley     NaN        29     NaN
# 4         Adams      James      B.        29      F.
# ...         ...        ...     ...       ...     ...
# 1694  Treadwell      David     NaN        29       D
# 1695     Trusty      Jacob     NaN        29       D
# 1696     Walker    Francis      H.        29       D
# 1697     Finley      James     NaN        29       D
# 1698       Tock      Cyrus     NaN        29       D
#
#                   Place of birth Enlistment date Enlistment location  \
# 0                       Maryland        1/4/1864          Bridgeport
# 1                         France      12/15/1863           New Haven
# 2       Torringford, Connecticut      12/24/1863            Hartford
# ...

# %%
df.drop(columns='Died in service')
# Out:
#       Last name First name MI/name  Regiment Company  \
# 0         Adams      James     NaN        29      I.
# 1         Adams      Henry      A.        29     NaN
# 2         Adams      Henry      E.        29     NaN
# 3        Abbott     Wesley     NaN        29     NaN
# 4         Adams      James      B.        29      F.
# ...         ...        ...     ...       ...     ...
# 1694  Treadwell      David     NaN        29       D
# 1695     Trusty      Jacob     NaN        29       D
# 1696     Walker    Francis      H.        29       D
# 1697     Finley      James     NaN        29       D
# 1698       Tock      Cyrus     NaN        29       D
#
#                   Place of birth Enlistment date Enlistment location  \
# 0                       Maryland        1/4/1864          Bridgeport
# 1                         France      12/15/1863           New Haven
# 2       Torringford, Connecticut      12/24/1863            Hartford
# ...

# %%
df.drop(columns='Muster out date')
# Out:
#       Last name First name MI/name  Regiment Company  \
# 0         Adams      James     NaN        29      I.
# 1         Adams      Henry      A.        29     NaN
# 2         Adams      Henry      E.        29     NaN
# 3        Abbott     Wesley     NaN        29     NaN
# 4         Adams      James      B.        29      F.
# ...         ...        ...     ...       ...     ...
# 1694  Treadwell      David     NaN        29       D
# 1695     Trusty      Jacob     NaN        29       D
# 1696     Walker    Francis      H.        29       D
# 1697     Finley      James     NaN        29       D
# 1698       Tock      Cyrus     NaN        29       D
#
#                   Place of birth Enlistment date Enlistment location  \
# 0                       Maryland        1/4/1864          Bridgeport
# 1                         France      12/15/1863           New Haven
# 2       Torringford, Connecticut      12/24/1863            Hartford
# ...
